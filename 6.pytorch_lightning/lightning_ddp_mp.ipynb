# %%
import pytorch_lightning as pl
import torch
from torch import nn
from torch.utils.data import DataLoader, Dataset
from pytorch_lightning.strategies import DDPStrategy
import torch.distributed as dist

# %%
class Encoder(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=2, padding=1)

    def forward(self, x):
        return self.conv(x), None, None

class Decoder(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv = nn.ConvTranspose2d(in_channels, out_channels, kernel_size=3, stride=2, padding=1, output_padding=1)

    def forward(self, x):
        return self.conv(x), None, None

class Conv3dLayer(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size):
        super().__init__()
        self.conv = nn.Conv3d(in_channels, out_channels, kernel_size)

    def forward(self, x):
        return self.conv(x)

class AutoencoderKL_MP(pl.LightningModule):
    def __init__(self, in_channels=3, out_channels=256, latent_channels=4, dev0=0, dev1=1):
        super().__init__()
        self.dev0 = dev0
        self.dev1 = dev1

        self.encoder = Encoder(in_channels, latent_channels).to(f'cuda:{self.dev0}')
        self.decoder = Decoder(latent_channels, out_channels).to(f'cuda:{self.dev1}')
        self.quant_conv = Conv3dLayer(2 * latent_channels, 2 * latent_channels, 1).to(f'cuda:{self.dev0}')
        self.post_quant_conv = Conv3dLayer(latent_channels, latent_channels, 1).to(f'cuda:{self.dev1}')

    def encode(self, x):
        h, _, _ = self.encoder(x)
        moments = self.quant_conv(h)
        return moments

    def decode(self, z):
        z = self.post_quant_conv(z)
        dec, _, _ = self.decoder(z)
        return dec

    def forward(self, x):
        x = x.to(f'cuda:{self.dev0}')
        moments = self.encode(x)
        z = moments.to(f'cuda:{self.dev1}')
        dec = self.decode(z)
        return dec

    def training_step(self, batch, batch_idx):
        x, y = batch
        x = x.to(f'cuda:{self.dev0}')
        y = y.to(f'cuda:{self.dev1}')
        output = self(x)
        loss = nn.functional.mse_loss(output, y)
        self.log('train_loss', loss)
        return loss

    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), lr=0.001)

class RandomDataset(Dataset):
    def __init__(self, size, length):
        self.len = length
        self.data = torch.randn(length, size)

    def __getitem__(self, index):
        return self.data[index], self.data[index]

    def __len__(self):
        return self.len

class RandomDataModule(pl.LightningDataModule):
    def __init__(self, size, length, batch_size):
        super().__init__()
        self.size = size
        self.length = length
        self.batch_size = batch_size

    def setup(self, stage=None):
        self.dataset = RandomDataset(self.size, self.length)

    def train_dataloader(self):
        return DataLoader(self.dataset, batch_size=self.batch_size)

class CustomDDPStrategy(DDPStrategy):
    def setup_environment(self):
        if not dist.is_initialized():
            dist.init_process_group(
                backend="nccl",
                init_method="env://"
            )
        world_size = dist.get_world_size()
        rank = dist.get_rank()

        group_0 = [0, 1]
        group_1 = [2, 3]
        if rank in group_0:
            self.process_group = dist.new_group(ranks=group_0)
        elif rank in group_1:
            self.process_group = dist.new_group(ranks=group_1)
        else:
            raise ValueError(f"Rank {rank} is not in any group")

        self.local_rank = rank % 2

        print(f"Global rank {rank} in process group {self.process_group}, local rank {self.local_rank}")

    def configure_ddp(self):
        self.model = torch.nn.parallel.DistributedDataParallel(
            self.model,
            device_ids=[self.local_rank],
            process_group=self.process_group
        )

    def setup(self, trainer):
        self.setup_environment()
        self.configure_ddp()
        trainer.model = self.model

# %%
from pytorch_lightning import Trainer

model = AutoencoderKL_MP()
data_module = RandomDataModule(size=32, length=10000, batch_size=32)

trainer = Trainer(
    strategy=CustomDDPStrategy(find_unused_parameters=False),
    accelerator="gpu",
    devices=[0, 1],  # Specify all 4 GPUs
    num_nodes=1,
    max_epochs=10,
)

trainer.fit(model, data_module)
# Out:
# ---------------------------------------------------------------------------
# MisconfigurationException                 Traceback (most recent call last)
# Cell In[3], line 6
#       3 model = AutoencoderKL_MP()
#       4 data_module = RandomDataModule(size=32, length=10000, batch_size=32)
# ----> 6 trainer = Trainer(
#       7     strategy=CustomDDPStrategy(find_unused_parameters=False),
#       8     accelerator="gpu",
#       9     devices=[0, 1],  # Specify all 4 GPUs
#      10     num_nodes=1,
#      11     max_epochs=10,
#      12 )
#      14 trainer.fit(model, data_module)
#
# File ~/anaconda3/envs/torch2/lib/python3.9/site-packages/pytorch_lightning/utilities/argparse.py:70, in _defaults_from_env_vars.<locals>.insert_env_defaults(self, *args, **kwargs)
#      67 kwargs = dict(list(env_variables.items()) + list(kwargs.items()))
#      69 # all args were already moved to kwargs
# ---> 70 return fn(self, **kwargs)
#
# File ~/anaconda3/envs/torch2/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:400, in Trainer.__init__(self, accelerator, strategy, devices, num_nodes, precision, logger, callbacks, fast_dev_run, max_epochs, min_epochs, max_steps, min_steps, max_time, limit_train_batches, limit_val_batches, limit_test_batches, limit_predict_batches, overfit_batches, val_check_interval, check_val_every_n_epoch, num_sanity_val_steps, log_every_n_steps, enable_checkpointing, enable_progress_bar, enable_model_summary, accumulate_grad_batches, gradient_clip_val, gradient_clip_algorithm, deterministic, benchmark, inference_mode, use_distributed_sampler, profiler, detect_anomaly, barebones, plugins, sync_batchnorm, reload_dataloaders_every_n_epochs, default_root_dir)
#     397 # init connectors
#     398 self._data_connector = _DataConnector(self)
# --> 400 self._accelerator_connector = _AcceleratorConnector(
#     401     devices=devices,
#     402     accelerator=accelerator,
#     403     strategy=strategy,
#     404     num_nodes=num_nodes,
#     405     sync_batchnorm=sync_batchnorm,
#     406     benchmark=benchmark,
#     407     use_distributed_sampler=use_distributed_sampler,
#     408     deterministic=deterministic,
#     409     precision=precision,
#     410     plugins=plugins,
#     411 )
#     412 self._logger_connector = _LoggerConnector(self)
#     413 self._callback_connector = _CallbackConnector(self)
#
# File ~/anaconda3/envs/torch2/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:162, in _AcceleratorConnector.__init__(self, devices, num_nodes, accelerator, strategy, plugins, precision, sync_batchnorm, benchmark, use_distributed_sampler, deterministic)
#     159 self.precision_plugin = self._check_and_init_precision()
#     161 # 6. Instantiate Strategy - Part 2
# --> 162 self._lazy_init_strategy()
#
# File ~/anaconda3/envs/torch2/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:580, in _AcceleratorConnector._lazy_init_strategy(self)
#     577 self.strategy._configure_launcher()
#     579 if _IS_INTERACTIVE and self.strategy.launcher and not self.strategy.launcher.is_interactive_compatible:
# --> 580     raise MisconfigurationException(
#     581         f"`Trainer(strategy={self._strategy_flag!r})` is not compatible with an interactive"
#     582         " environment. Run your code as a script, or choose a notebook-compatible strategy:"
#     583         f" `Trainer(strategy='ddp_notebook')`."
#     584         " In case you are spawning processes yourself, make sure to include the Trainer"
#     585         " creation inside the worker function."
#     586     )
#     588 # TODO: should be moved to _check_strategy_and_fallback().
#     589 # Current test check precision first, so keep this check here to meet error order
#     590 if isinstance(self.accelerator, XLAAccelerator) and not isinstance(
#     591     self.strategy, (SingleDeviceXLAStrategy, XLAStrategy)
#     592 ):
#
# MisconfigurationException: `Trainer(strategy=<__main__.CustomDDPStrategy object at 0x7f1dd84431c0>)` is not compatible with an interactive environment. Run your code as a script, or choose a notebook-compatible strategy: `Trainer(strategy='ddp_notebook')`. In case you are spawning processes yourself, make sure to include the Trainer creation inside the worker function.
