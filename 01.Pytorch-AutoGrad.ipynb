# %%
import torch, torchvision

# %% [markdown]
# # GPU Check
# ---

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# # Model Load

# %%
model = torchvision.models.resnet18(pretrained=True)
data = torch.rand(1, 3, 64, 64)
labels = torch.rand(1, 1000)

# %%
data.numpy()
# Out:
# array([[[[0.8335438 , 0.28140712, 0.8501863 , ..., 0.08919442,
#           0.00481218, 0.6175365 ],
#          [0.29640263, 0.60647655, 0.26799774, ..., 0.83481234,
#           0.63907677, 0.78566027],
#          [0.81549144, 0.7647918 , 0.0785616 , ..., 0.21540976,
#           0.05701822, 0.5370347 ],
#          ...,
#          [0.61064315, 0.5421125 , 0.22154307, ..., 0.7433896 ,
#           0.37267256, 0.23645967],
#          [0.3393036 , 0.5362612 , 0.8353816 , ..., 0.9525679 ,
#           0.0090754 , 0.25519747],
#          [0.02438271, 0.36653572, 0.84238464, ..., 0.8494267 ,
#           0.580447  , 0.46284384]],
#
#         [[0.08326375, 0.15619683, 0.03041935, ..., 0.45096898,
#           0.679757  , 0.82344514],
#          [0.24082571, 0.52228814, 0.3576421 , ..., 0.2316019 ,
#           0.3478691 , 0.33452654],
#          [0.67872864, 0.1491614 , 0.71433544, ..., 0.7266917 ,
#           0.21321201, 0.9840786 ],
#          ...,
#          [0.00767672, 0.3594693 , 0.40966266, ..., 0.75060266,
#           0.09186625, 0.47301614],
#          [0.70017594, 0.03952456, 0.1458351 , ..., 0.26509196,
#           0.4851315 , 0.59473854],
#          [0.8127773 , 0.57446074, 0.06443268, ..., 0.48715472,
#           0.37471145, 0.2218889 ]],
#
#         [[0.9915906 , 0.78818125, 0.9793429 , ..., 0.9482573 ,
#           0.1787185 , 0.26800376],
#          [0.6668803 , 0.9359452 , 0.93129444, ..., 0.7090273 ,
#           0.0906707 , 0.75537246],
#          [0.9375618 , 0.7711367 , 0.2131561 , ..., 0.13515389,
#           0.7569465 , 0.41239375],
#          ...,
#          [0.4621563 , 0.8388703 , 0.17823601, ..., 0.6115795 ,
#           0.17476034, 0.82490563],
#          [0.25344986, 0.13674343, 0.18440342, ..., 0.38903135,
#           0.54893917, 0.44662642],
#          [0.9829738 , 0.20417011, 0.3822773 , ..., 0.60977715,
#           0.7070387 , 0.4933625 ]]]], dtype=float32)

# %%
labels.numpy()
# Out:
# array([[0.70320845, 0.7584678 , 0.6260037 , 0.00609529, 0.19023633,
#         0.42018825, 0.10333043, 0.41852593, 0.8902591 , 0.5757377 ,
#         0.5331904 , 0.8466513 , 0.44572103, 0.8287859 , 0.46107882,
#         0.0937497 , 0.09704739, 0.63301873, 0.679656  , 0.9470375 ,
#         0.94760126, 0.4539081 , 0.5173742 , 0.30830556, 0.2981987 ,
#         0.10729581, 0.64772695, 0.4072253 , 0.46949732, 0.66320527,
#         0.35316718, 0.88099486, 0.31291693, 0.7831332 , 0.74823534,
#         0.64143306, 0.1045239 , 0.7012206 , 0.92451787, 0.3477164 ,
#         0.32210922, 0.4341786 , 0.01679987, 0.505821  , 0.60057145,
#         0.44310838, 0.4237374 , 0.46966404, 0.08632958, 0.8978664 ,
#         0.1459282 , 0.30328637, 0.11279857, 0.2928486 , 0.91905403,
#         0.62111956, 0.13771987, 0.04240656, 0.5880577 , 0.9741091 ,
#         0.64709723, 0.21860242, 0.18502164, 0.18761283, 0.41925544,
#         0.27139896, 0.34240854, 0.05730939, 0.22203392, 0.99239737,
#         0.14317942, 0.42416668, 0.81503206, 0.8833809 , 0.81241834,
#         0.34663498, 0.22709113, 0.750034  , 0.35992938, 0.20708889,
#         0.29617727, 0.19406748, 0.44061792, 0.73843324, 0.6952697 ]],
#       dtype=float32)

# %%
prediction = model(data)

# %%
loss = (prediction - labels).sum()
loss.backward() # backward pass

# %%
loss
# Out:
# tensor(-500.2837, grad_fn=<SumBackward0>)

# %%
optim = torch.optim.SGD(model.parameters(), lr=1e-2, momentum=0.9)

# %%
optim
# Out:
# SGD (
# Parameter Group 0
#     dampening: 0
#     lr: 0.01
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 0
# )

# %%
optim.step() #gradient descent

# %% [markdown]
# # Differentiation in Autograd
# ---

# %%
a = torch.tensor([2., 3.], requires_grad=True)
b = torch.tensor([6., 4.], requires_grad=True)

# %%
Q = 3*a**3 - b**2

# %%
external_grad = torch.tensor([1., 1.])
Q.backward(gradient=external_grad)

# %%
print(9*a**2 == a.grad)
print(-2*b == b.grad)
# Out:
# tensor([True, True])
# tensor([True, True])

# %%
Q
# Out:
# tensor([-12.,  65.], grad_fn=<SubBackward0>)

# %% [markdown]
# # Computational Graph

# %%
data = torch.rand(1, 3, 64, 64)
labels = torch.rand(1, 10)
test_data = torch.rand(1, 3, 64,64)

# %%
x = torch.rand(5, 5)
y = torch.rand(5, 5)
z = torch.rand((5, 5), requires_grad=True)

a = x + y
print(f"Does `a` require gradients? : {a.requires_grad}")
b = x + z
print(f"Does `b` require gradients?: {b.requires_grad}")
# Out:
# Does `a` require gradients? : False
# Does `b` require gradients?: True

# %%
from torch import nn, optim

model = torchvision.models.resnet18(pretrained=True)

# Freeze all the parameters in the network
for param in model.parameters():
    param.requires_grad = False

# %%
model.fc = nn.Linear(512,10)

# %%
optimizer = optim.SGD(model.fc.parameters(), lr=1e-2, momentum=0.9)

# %%
prediction = model(data)

# %%
loss = (prediction - labels).sum()
loss.backward() # backward pass

# %%
optim = torch.optim.SGD(model.parameters(), lr=1e-2, momentum=0.9)

# %%
optim.step()

# %%
model(test_data).detach().numpy()
# Out:
# array([[-4.6708746, -4.2578926, -4.6880746, -4.7507253, -4.450863 ,
#         -5.5752482, -4.9015846, -3.6900647, -4.780111 , -3.3442442]],
#       dtype=float32)
